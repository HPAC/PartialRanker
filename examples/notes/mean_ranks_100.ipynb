# %%
from algorithm_ranking import MeasurementsVisualizer, MeasurementsSimulator, RankBFS, CompareAlgs

# %%
cfg = {}
cfg['alg0']  = [0.1,0.02] #[mean, std]
cfg['alg1']  = [0.15,0.01]
cfg['alg2']  = [0.16,0.02]
cfg['alg3']  = [0.17,0.04]
cfg['alg4']  = [0.20,0.02]
h0 = list(cfg.keys())

# %%
cfg = {}
mu = 0.1
sig = 0.02
for i in range(100):
    alg = 'alg{}'.format(i)
    cfg[alg] = [mu, sig]
    mu = mu+0.01

# %%
ms = MeasurementsSimulator(cfg, 'normal', seed=152)   
ms.measure(30,1)
data = ms.get_alg_measurements()
h0 = list(cfg.keys())
mv = MeasurementsVisualizer(data, h0)

# %%
fig = mv.show_measurements_violinplot(h0,scale=0.2)

# %%
compareAlgs = CompareAlgs(data, h0)

# %%
rank = RankBFS(h0,compareAlgs)
# Out:
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# Adding edge from alg2 to alg3
# Adding edge from alg3 to alg4
# Adding edge from alg4 to alg5
# Adding edge from alg5 to alg6
# Adding edge from alg6 to alg7
# Adding edge from alg7 to alg8
# Adding edge from alg8 to alg9
# Adding edge from alg9 to alg10
# Adding edge from alg10 to alg11
# Adding edge from alg11 to alg12
# Adding edge from alg12 to alg13
# Adding edge from alg13 to alg14
# Adding edge from alg14 to alg15
# Adding edge from alg15 to alg16
# Adding edge from alg16 to alg17
# Adding edge from alg17 to alg18
# Adding edge from alg18 to alg19
# Adding edge from alg19 to alg20
# Adding edge from alg20 to alg21
# Adding edge from alg21 to alg22
# Adding edge from alg22 to alg23
# Adding edge from alg23 to alg24
# Adding edge from alg24 to alg25
# Adding edge from alg25 to alg26
# Adding edge from alg26 to alg27
# Adding edge from alg27 to alg28
# Adding edge from alg28 to alg29
# Adding edge from alg29 to alg30
# Adding edge from alg30 to alg31
# Adding edge from alg31 to alg32
# Adding edge from alg32 to alg33
# Adding edge from alg33 to alg34
# Adding edge from alg34 to alg35
# Adding edge from alg35 to alg36
# Adding edge from alg36 to alg37
# Adding edge from alg37 to alg38
# Adding edge from alg38 to alg39
# Adding edge from alg39 to alg40
# Adding edge from alg40 to alg41
# Adding edge from alg41 to alg42
# Adding edge from alg42 to alg43
# Adding edge from alg43 to alg44
# Adding edge from alg44 to alg45
# Adding edge from alg45 to alg46
# Adding edge from alg46 to alg47
# Adding edge from alg47 to alg48
# Adding edge from alg48 to alg49
# Adding edge from alg49 to alg50
# Adding edge from alg50 to alg51
# Adding edge from alg51 to alg52
# Adding edge from alg52 to alg53
# Adding edge from alg53 to alg54
# Adding edge from alg54 to alg55
# Adding edge from alg55 to alg56
# Adding edge from alg56 to alg57
# Adding edge from alg57 to alg58
# Adding edge from alg58 to alg59
# Adding edge from alg59 to alg60
# Adding edge from alg60 to alg61
# Adding edge from alg61 to alg62
# Adding edge from alg62 to alg63
# Adding edge from alg63 to alg64
# Adding edge from alg64 to alg65
# Adding edge from alg65 to alg66
# Adding edge from alg66 to alg67
# Adding edge from alg67 to alg68
# Adding edge from alg68 to alg69
# Adding edge from alg69 to alg70
# Adding edge from alg70 to alg71
# Adding edge from alg71 to alg72
# Adding edge from alg72 to alg73
# Adding edge from alg73 to alg74
# Adding edge from alg74 to alg75
# Adding edge from alg75 to alg76
# Adding edge from alg76 to alg77
# Adding edge from alg77 to alg78
# Adding edge from alg78 to alg79
# Adding edge from alg79 to alg80
# Adding edge from alg80 to alg81
# Adding edge from alg81 to alg82
# Adding edge from alg82 to alg83
# Adding edge from alg83 to alg84
# Adding edge from alg84 to alg85
# Adding edge from alg85 to alg86
# Adding edge from alg86 to alg87
# Adding edge from alg87 to alg88
# Adding edge from alg88 to alg89
# Adding edge from alg89 to alg90
# Adding edge from alg90 to alg91
# Adding edge from alg91 to alg92
# Adding edge from alg92 to alg93
# Adding edge from alg93 to alg94
# Adding edge from alg94 to alg95
# Adding edge from alg95 to alg96
# Adding edge from alg96 to alg97
# Adding edge from alg97 to alg98
# Adding edge from alg98 to alg99

# %%
history, ranks = rank.rank_algorithms(q_min=25,q_max=75)
# Out:
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# Adding edge from alg2 to alg3
# Adding edge from alg3 to alg4
# Adding edge from alg4 to alg5
# Adding edge from alg5 to alg6
# Adding edge from alg6 to alg7
# Adding edge from alg7 to alg8
# Adding edge from alg8 to alg9
# Adding edge from alg9 to alg10
# Adding edge from alg10 to alg11
# Adding edge from alg11 to alg12
# Adding edge from alg12 to alg13
# Adding edge from alg13 to alg14
# Adding edge from alg14 to alg15
# Adding edge from alg15 to alg16
# Adding edge from alg16 to alg17
# Adding edge from alg17 to alg18
# Adding edge from alg18 to alg19
# Adding edge from alg19 to alg20
# Adding edge from alg20 to alg21
# Adding edge from alg21 to alg22
# Adding edge from alg22 to alg23
# Adding edge from alg23 to alg24
# Adding edge from alg24 to alg25
# Adding edge from alg25 to alg26
# Adding edge from alg26 to alg27
# Adding edge from alg27 to alg28
# Adding edge from alg28 to alg29
# Adding edge from alg29 to alg30
# Adding edge from alg30 to alg31
# Adding edge from alg31 to alg32
# Adding edge from alg32 to alg33
# Adding edge from alg33 to alg34
# Adding edge from alg34 to alg35
# Adding edge from alg35 to alg36
# Adding edge from alg36 to alg37
# Adding edge from alg37 to alg38
# Adding edge from alg38 to alg39
# Adding edge from alg39 to alg40
# Adding edge from alg40 to alg41
# Adding edge from alg41 to alg42
# Adding edge from alg42 to alg43
# Adding edge from alg43 to alg44
# Adding edge from alg44 to alg45
# Adding edge from alg45 to alg46
# Adding edge from alg46 to alg47
# Adding edge from alg47 to alg48
# Adding edge from alg48 to alg49
# Adding edge from alg49 to alg50
# Adding edge from alg50 to alg51
# Adding edge from alg51 to alg52
# Adding edge from alg52 to alg53
# Adding edge from alg53 to alg54
# Adding edge from alg54 to alg55
# Adding edge from alg55 to alg56
# Adding edge from alg56 to alg57
# Adding edge from alg57 to alg58
# Adding edge from alg58 to alg59
# Adding edge from alg59 to alg60
# Adding edge from alg60 to alg61
# Adding edge from alg61 to alg62
# Adding edge from alg62 to alg63
# Adding edge from alg63 to alg64
# Adding edge from alg64 to alg65
# Adding edge from alg65 to alg66
# Adding edge from alg66 to alg67
# Adding edge from alg67 to alg68
# Adding edge from alg68 to alg69
# Adding edge from alg69 to alg70
# Adding edge from alg70 to alg71
# Adding edge from alg71 to alg72
# Adding edge from alg72 to alg73
# Adding edge from alg73 to alg74
# Adding edge from alg74 to alg75
# Adding edge from alg75 to alg76
# Adding edge from alg76 to alg77
# Adding edge from alg77 to alg78
# Adding edge from alg78 to alg79
# Adding edge from alg79 to alg80
# Adding edge from alg80 to alg81
# Adding edge from alg81 to alg82
# Adding edge from alg82 to alg83
# Adding edge from alg83 to alg84
# Adding edge from alg84 to alg85
# Adding edge from alg85 to alg86
# Adding edge from alg86 to alg87
# Adding edge from alg87 to alg88
# Adding edge from alg88 to alg89
# Adding edge from alg89 to alg90
# Adding edge from alg90 to alg91
# Adding edge from alg91 to alg92
# Adding edge from alg92 to alg93
# Adding edge from alg93 to alg94
# Adding edge from alg94 to alg95
# Adding edge from alg95 to alg96
# Adding edge from alg96 to alg97
# Adding edge from alg97 to alg98
# Adding edge from alg98 to alg99
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# Adding edge from alg0 to alg3
# Adding edge from alg1 to alg3
# ['alg2', 'alg0', 'alg1'] alg3
# Removing edge from alg2 to alg3
# ['alg3'] alg4
# Adding edge from alg0 to alg4
# Adding edge from alg1 to alg4
# Adding edge from alg2 to alg4
# Removing edge from alg3 to alg4
# Adding edge from alg3 to alg5
# ['alg0', 'alg1', 'alg2'] alg4
# Removing edge from alg2 to alg4
# ['alg4', 'alg3'] alg5
# Removing edge from alg4 to alg5
# ['alg5'] alg6
# Adding edge from alg3 to alg6
# Adding edge from alg4 to alg6
# Removing edge from alg5 to alg6
# Adding edge from alg5 to alg7
# ['alg3', 'alg4'] alg6
# Adding edge from alg0 to alg6
# Adding edge from alg1 to alg6
# Adding edge from alg2 to alg6
# Removing edge from alg3 to alg6
# Removing edge from alg4 to alg6
# Removing edge from alg6 to alg7
# ['alg0', 'alg1', 'alg2'] alg6
# ['alg5'] alg7
# ['alg7'] alg8
# Adding edge from alg5 to alg8
# Removing edge from alg7 to alg8
# Adding edge from alg7 to alg9
# ['alg5'] alg8
# ['alg8', 'alg7'] alg9
# Adding edge from alg5 to alg9
# Removing edge from alg8 to alg9
# Removing edge from alg7 to alg9
# Adding edge from alg7 to alg10
# Adding edge from alg8 to alg10
# ['alg5'] alg9
# ['alg9', 'alg7', 'alg8'] alg10
# Removing edge from alg9 to alg10
# ['alg10'] alg11
# Adding edge from alg7 to alg11
# Adding edge from alg8 to alg11
# Adding edge from alg9 to alg11
# Removing edge from alg10 to alg11
# Adding edge from alg10 to alg12
# ['alg7', 'alg8', 'alg9'] alg11
# ['alg11', 'alg10'] alg12
# Adding edge from alg7 to alg12
# Adding edge from alg8 to alg12
# Adding edge from alg9 to alg12
# Removing edge from alg11 to alg12
# Removing edge from alg10 to alg12
# Adding edge from alg10 to alg13
# Adding edge from alg11 to alg13
# ['alg7', 'alg8', 'alg9'] alg12
# ['alg12', 'alg10', 'alg11'] alg13
# Removing edge from alg12 to alg13
# Removing edge from alg11 to alg13
# ['alg13'] alg14
# Adding edge from alg10 to alg14
# Adding edge from alg11 to alg14
# Adding edge from alg12 to alg14
# Removing edge from alg13 to alg14
# Adding edge from alg13 to alg15
# ['alg10', 'alg11', 'alg12'] alg14
# ['alg14', 'alg13'] alg15
# Adding edge from alg10 to alg15
# Adding edge from alg11 to alg15
# Adding edge from alg12 to alg15
# Removing edge from alg14 to alg15
# Removing edge from alg13 to alg15
# Adding edge from alg13 to alg16
# Adding edge from alg14 to alg16
# ['alg10', 'alg11', 'alg12'] alg15
# ['alg15', 'alg13', 'alg14'] alg16
# Removing edge from alg15 to alg16
# Removing edge from alg14 to alg16
# ['alg16'] alg17
# Adding edge from alg13 to alg17
# Adding edge from alg14 to alg17
# Adding edge from alg15 to alg17
# Removing edge from alg16 to alg17
# Adding edge from alg16 to alg18
# ['alg13', 'alg14', 'alg15'] alg17
# Removing edge from alg15 to alg17
# ['alg17', 'alg16'] alg18
# Adding edge from alg13 to alg18
# Adding edge from alg14 to alg18
# Adding edge from alg15 to alg18
# Removing edge from alg17 to alg18
# Removing edge from alg16 to alg18
# Adding edge from alg16 to alg19
# Adding edge from alg17 to alg19
# ['alg13', 'alg14', 'alg15'] alg18
# Removing edge from alg15 to alg18
# ['alg18', 'alg16', 'alg17'] alg19
# Removing edge from alg18 to alg19
# Removing edge from alg17 to alg19
# ['alg19'] alg20
# Adding edge from alg16 to alg20
# Adding edge from alg17 to alg20
# Adding edge from alg18 to alg20
# Removing edge from alg19 to alg20
# Adding edge from alg19 to alg21
# ['alg16', 'alg17', 'alg18'] alg20
# ['alg20', 'alg19'] alg21
# Adding edge from alg16 to alg21
# Adding edge from alg17 to alg21
# Adding edge from alg18 to alg21
# Removing edge from alg20 to alg21
# Removing edge from alg19 to alg21
# Adding edge from alg19 to alg22
# Adding edge from alg20 to alg22
# ['alg16', 'alg17', 'alg18'] alg21
# ['alg21', 'alg19', 'alg20'] alg22
# Adding edge from alg16 to alg22
# Adding edge from alg17 to alg22
# Adding edge from alg18 to alg22
# Removing edge from alg21 to alg22
# Removing edge from alg19 to alg22
# Removing edge from alg20 to alg22
# Adding edge from alg19 to alg23
# Adding edge from alg20 to alg23
# Adding edge from alg21 to alg23
# ['alg16', 'alg17', 'alg18'] alg22
# ['alg22', 'alg19', 'alg20', 'alg21'] alg23
# Removing edge from alg22 to alg23
# Removing edge from alg21 to alg23
# ['alg23'] alg24
# Adding edge from alg19 to alg24
# Adding edge from alg20 to alg24
# Adding edge from alg21 to alg24
# Adding edge from alg22 to alg24
# Removing edge from alg23 to alg24
# Adding edge from alg23 to alg25
# ['alg19', 'alg20', 'alg21', 'alg22'] alg24
# Removing edge from alg21 to alg24
# Removing edge from alg22 to alg24
# ['alg24', 'alg23'] alg25
# Adding edge from alg19 to alg25
# Adding edge from alg20 to alg25
# Adding edge from alg21 to alg25
# Adding edge from alg22 to alg25
# Removing edge from alg24 to alg25
# Removing edge from alg23 to alg25
# Adding edge from alg23 to alg26
# Adding edge from alg24 to alg26
# ['alg19', 'alg20', 'alg21', 'alg22'] alg25
# ['alg25', 'alg23', 'alg24'] alg26
# Removing edge from alg25 to alg26
# ['alg26'] alg27
# Adding edge from alg23 to alg27
# Adding edge from alg24 to alg27
# Adding edge from alg25 to alg27
# Removing edge from alg26 to alg27
# Adding edge from alg26 to alg28
# ['alg23', 'alg24', 'alg25'] alg27
# Removing edge from alg25 to alg27
# ['alg27', 'alg26'] alg28
# Adding edge from alg23 to alg28
# Adding edge from alg24 to alg28
# Adding edge from alg25 to alg28
# Removing edge from alg27 to alg28
# Removing edge from alg26 to alg28
# Adding edge from alg26 to alg29
# Adding edge from alg27 to alg29
# ['alg23', 'alg24', 'alg25'] alg28
# Removing edge from alg25 to alg28
# ['alg28', 'alg26', 'alg27'] alg29
# Removing edge from alg28 to alg29
# ['alg29'] alg30
# Adding edge from alg26 to alg30
# Adding edge from alg27 to alg30
# Adding edge from alg28 to alg30
# Removing edge from alg29 to alg30
# Adding edge from alg29 to alg31
# ['alg26', 'alg27', 'alg28'] alg30
# ['alg30', 'alg29'] alg31
# Adding edge from alg26 to alg31
# Adding edge from alg27 to alg31
# Adding edge from alg28 to alg31
# Removing edge from alg30 to alg31
# Removing edge from alg29 to alg31
# Adding edge from alg29 to alg32
# Adding edge from alg30 to alg32
# ['alg26', 'alg27', 'alg28'] alg31
# ['alg31', 'alg29', 'alg30'] alg32
# Adding edge from alg26 to alg32
# Adding edge from alg27 to alg32
# Adding edge from alg28 to alg32
# Removing edge from alg31 to alg32
# Removing edge from alg29 to alg32
# Removing edge from alg30 to alg32
# Adding edge from alg29 to alg33
# Adding edge from alg30 to alg33
# Adding edge from alg31 to alg33
# ['alg26', 'alg27', 'alg28'] alg32
# ['alg32', 'alg29', 'alg30', 'alg31'] alg33
# Removing edge from alg32 to alg33
# Removing edge from alg30 to alg33
# Removing edge from alg31 to alg33
# ['alg33'] alg34
# Adding edge from alg29 to alg34
# Adding edge from alg30 to alg34
# Adding edge from alg31 to alg34
# Adding edge from alg32 to alg34
# Removing edge from alg33 to alg34
# Adding edge from alg33 to alg35
# ['alg29', 'alg30', 'alg31', 'alg32'] alg34
# Removing edge from alg32 to alg34
# ['alg34', 'alg33'] alg35
# Adding edge from alg29 to alg35
# Adding edge from alg30 to alg35
# Adding edge from alg31 to alg35
# Adding edge from alg32 to alg35
# Removing edge from alg34 to alg35
# Removing edge from alg33 to alg35
# Adding edge from alg33 to alg36
# Adding edge from alg34 to alg36
# ['alg29', 'alg30', 'alg31', 'alg32'] alg35
# Removing edge from alg32 to alg35
# ['alg35', 'alg33', 'alg34'] alg36
# Adding edge from alg29 to alg36
# Adding edge from alg30 to alg36
# Adding edge from alg31 to alg36
# Adding edge from alg32 to alg36
# Removing edge from alg35 to alg36
# Removing edge from alg33 to alg36
# Removing edge from alg34 to alg36
# Adding edge from alg33 to alg37
# Adding edge from alg34 to alg37
# Adding edge from alg35 to alg37
# ['alg29', 'alg30', 'alg31', 'alg32'] alg36
# ['alg36', 'alg33', 'alg34', 'alg35'] alg37
# Removing edge from alg36 to alg37
# Removing edge from alg34 to alg37
# Removing edge from alg35 to alg37
# ['alg37'] alg38
# Adding edge from alg33 to alg38
# Adding edge from alg34 to alg38
# Adding edge from alg35 to alg38
# Adding edge from alg36 to alg38
# Removing edge from alg37 to alg38
# Adding edge from alg37 to alg39
# ['alg33', 'alg34', 'alg35', 'alg36'] alg38
# Removing edge from alg34 to alg38
# Removing edge from alg36 to alg38
# ['alg38', 'alg37'] alg39
# Removing edge from alg38 to alg39
# ['alg39'] alg40
# Adding edge from alg37 to alg40
# Adding edge from alg38 to alg40
# Removing edge from alg39 to alg40
# Adding edge from alg39 to alg41
# ['alg37', 'alg38'] alg40
# ['alg40', 'alg39'] alg41
# Adding edge from alg37 to alg41
# Adding edge from alg38 to alg41
# Removing edge from alg40 to alg41
# Removing edge from alg39 to alg41
# Adding edge from alg39 to alg42
# Adding edge from alg40 to alg42
# ['alg37', 'alg38'] alg41
# ['alg41', 'alg39', 'alg40'] alg42
# Removing edge from alg41 to alg42
# Removing edge from alg40 to alg42
# ['alg42'] alg43
# Adding edge from alg39 to alg43
# Adding edge from alg40 to alg43
# Adding edge from alg41 to alg43
# Removing edge from alg42 to alg43
# Adding edge from alg42 to alg44
# ['alg39', 'alg40', 'alg41'] alg43
# Removing edge from alg41 to alg43
# ['alg43', 'alg42'] alg44
# Adding edge from alg39 to alg44
# Adding edge from alg40 to alg44
# Adding edge from alg41 to alg44
# Removing edge from alg43 to alg44
# Removing edge from alg42 to alg44
# Adding edge from alg42 to alg45
# Adding edge from alg43 to alg45
# ['alg39', 'alg40', 'alg41'] alg44
# ['alg44', 'alg42', 'alg43'] alg45
# Adding edge from alg39 to alg45
# Adding edge from alg40 to alg45
# Adding edge from alg41 to alg45
# Removing edge from alg44 to alg45
# Removing edge from alg42 to alg45
# Removing edge from alg43 to alg45
# Adding edge from alg42 to alg46
# Adding edge from alg43 to alg46
# Adding edge from alg44 to alg46
# ['alg39', 'alg40', 'alg41'] alg45
# ['alg45', 'alg42', 'alg43', 'alg44'] alg46
# Removing edge from alg45 to alg46
# Removing edge from alg43 to alg46
# Removing edge from alg44 to alg46
# ['alg46'] alg47
# ['alg47'] alg48
# Adding edge from alg46 to alg48
# Removing edge from alg47 to alg48
# Adding edge from alg47 to alg49
# ['alg46'] alg48
# ['alg48', 'alg47'] alg49
# Adding edge from alg46 to alg49
# Removing edge from alg48 to alg49
# Removing edge from alg47 to alg49
# Adding edge from alg47 to alg50
# Adding edge from alg48 to alg50
# ['alg46'] alg49
# ['alg49', 'alg47', 'alg48'] alg50
# ['alg50'] alg51
# Adding edge from alg47 to alg51
# Adding edge from alg48 to alg51
# Adding edge from alg49 to alg51
# Removing edge from alg50 to alg51
# Adding edge from alg50 to alg52
# ['alg47', 'alg48', 'alg49'] alg51
# ['alg51', 'alg50'] alg52
# Adding edge from alg47 to alg52
# Adding edge from alg48 to alg52
# Adding edge from alg49 to alg52
# Removing edge from alg51 to alg52
# Removing edge from alg50 to alg52
# Adding edge from alg50 to alg53
# Adding edge from alg51 to alg53
# ['alg47', 'alg48', 'alg49'] alg52
# ['alg52', 'alg50', 'alg51'] alg53
# Adding edge from alg47 to alg53
# Adding edge from alg48 to alg53
# Adding edge from alg49 to alg53
# Removing edge from alg52 to alg53
# Removing edge from alg50 to alg53
# Removing edge from alg51 to alg53
# Adding edge from alg50 to alg54
# Adding edge from alg51 to alg54
# Adding edge from alg52 to alg54
# ['alg47', 'alg48', 'alg49'] alg53
# ['alg53', 'alg50', 'alg51', 'alg52'] alg54
# Removing edge from alg53 to alg54
# Removing edge from alg52 to alg54
# ['alg54'] alg55
# Adding edge from alg50 to alg55
# Adding edge from alg51 to alg55
# Adding edge from alg52 to alg55
# Adding edge from alg53 to alg55
# Removing edge from alg54 to alg55
# Adding edge from alg54 to alg56
# ['alg50', 'alg51', 'alg52', 'alg53'] alg55
# Removing edge from alg52 to alg55
# Removing edge from alg53 to alg55
# ['alg55', 'alg54'] alg56
# Adding edge from alg50 to alg56
# Adding edge from alg51 to alg56
# Adding edge from alg52 to alg56
# Adding edge from alg53 to alg56
# Removing edge from alg55 to alg56
# Removing edge from alg54 to alg56
# Adding edge from alg54 to alg57
# Adding edge from alg55 to alg57
# ['alg50', 'alg51', 'alg52', 'alg53'] alg56
# ['alg56', 'alg54', 'alg55'] alg57
# Removing edge from alg56 to alg57
# Removing edge from alg55 to alg57
# ['alg57'] alg58
# ['alg58'] alg59
# Adding edge from alg57 to alg59
# Removing edge from alg58 to alg59
# Adding edge from alg58 to alg60
# ['alg57'] alg59
# Adding edge from alg54 to alg59
# Adding edge from alg55 to alg59
# Adding edge from alg56 to alg59
# Removing edge from alg57 to alg59
# Removing edge from alg59 to alg60
# ['alg54', 'alg55', 'alg56'] alg59
# ['alg58'] alg60
# Adding edge from alg57 to alg60
# Adding edge from alg59 to alg60
# Removing edge from alg58 to alg60
# Adding edge from alg58 to alg61
# ['alg57', 'alg59'] alg60
# Removing edge from alg59 to alg60
# ['alg60', 'alg58'] alg61
# Adding edge from alg57 to alg61
# Adding edge from alg59 to alg61
# Removing edge from alg60 to alg61
# Removing edge from alg58 to alg61
# Adding edge from alg58 to alg62
# Adding edge from alg60 to alg62
# ['alg57', 'alg59'] alg61
# Removing edge from alg59 to alg61
# ['alg61', 'alg58', 'alg60'] alg62
# Removing edge from alg61 to alg62
# Removing edge from alg60 to alg62
# ['alg62'] alg63
# Adding edge from alg58 to alg63
# Adding edge from alg60 to alg63
# Adding edge from alg61 to alg63
# Removing edge from alg62 to alg63
# Adding edge from alg62 to alg64
# ['alg58', 'alg60', 'alg61'] alg63
# Removing edge from alg61 to alg63
# ['alg63', 'alg62'] alg64
# Adding edge from alg58 to alg64
# Adding edge from alg60 to alg64
# Adding edge from alg61 to alg64
# Removing edge from alg63 to alg64
# Removing edge from alg62 to alg64
# Adding edge from alg62 to alg65
# Adding edge from alg63 to alg65
# ['alg58', 'alg60', 'alg61'] alg64
# Removing edge from alg61 to alg64
# ['alg64', 'alg62', 'alg63'] alg65
# Adding edge from alg58 to alg65
# Adding edge from alg60 to alg65
# Adding edge from alg61 to alg65
# Removing edge from alg64 to alg65
# Removing edge from alg62 to alg65
# Removing edge from alg63 to alg65
# Adding edge from alg62 to alg66
# Adding edge from alg63 to alg66
# Adding edge from alg64 to alg66
# ['alg58', 'alg60', 'alg61'] alg65
# ['alg65', 'alg62', 'alg63', 'alg64'] alg66
# Removing edge from alg65 to alg66
# Removing edge from alg63 to alg66
# Removing edge from alg64 to alg66
# ['alg66'] alg67
# Adding edge from alg62 to alg67
# Adding edge from alg63 to alg67
# Adding edge from alg64 to alg67
# Adding edge from alg65 to alg67
# Removing edge from alg66 to alg67
# Adding edge from alg66 to alg68
# ['alg62', 'alg63', 'alg64', 'alg65'] alg67
# Removing edge from alg65 to alg67
# ['alg67', 'alg66'] alg68
# Removing edge from alg67 to alg68
# ['alg68'] alg69
# Adding edge from alg66 to alg69
# Adding edge from alg67 to alg69
# Removing edge from alg68 to alg69
# Adding edge from alg68 to alg70
# ['alg66', 'alg67'] alg69
# Removing edge from alg67 to alg69
# ['alg69', 'alg68'] alg70
# Adding edge from alg66 to alg70
# Adding edge from alg67 to alg70
# Removing edge from alg69 to alg70
# Removing edge from alg68 to alg70
# Adding edge from alg68 to alg71
# Adding edge from alg69 to alg71
# ['alg66', 'alg67'] alg70
# ['alg70', 'alg68', 'alg69'] alg71
# Removing edge from alg70 to alg71
# Removing edge from alg69 to alg71
# ['alg71'] alg72
# Adding edge from alg68 to alg72
# Adding edge from alg69 to alg72
# Adding edge from alg70 to alg72
# Removing edge from alg71 to alg72
# Adding edge from alg71 to alg73
# ['alg68', 'alg69', 'alg70'] alg72
# Removing edge from alg70 to alg72
# ['alg72', 'alg71'] alg73
# Removing edge from alg72 to alg73
# ['alg73'] alg74
# Adding edge from alg71 to alg74
# Adding edge from alg72 to alg74
# Removing edge from alg73 to alg74
# Adding edge from alg73 to alg75
# ['alg71', 'alg72'] alg74
# Removing edge from alg72 to alg74
# ['alg74', 'alg73'] alg75
# Adding edge from alg71 to alg75
# Adding edge from alg72 to alg75
# Removing edge from alg74 to alg75
# Removing edge from alg73 to alg75
# Adding edge from alg73 to alg76
# Adding edge from alg74 to alg76
# ['alg71', 'alg72'] alg75
# Removing edge from alg72 to alg75
# ['alg75', 'alg73', 'alg74'] alg76
# Removing edge from alg75 to alg76
# ['alg76'] alg77
# Adding edge from alg73 to alg77
# Adding edge from alg74 to alg77
# Adding edge from alg75 to alg77
# Removing edge from alg76 to alg77
# Adding edge from alg76 to alg78
# ['alg73', 'alg74', 'alg75'] alg77
# ['alg77', 'alg76'] alg78
# Adding edge from alg73 to alg78
# Adding edge from alg74 to alg78
# Adding edge from alg75 to alg78
# Removing edge from alg77 to alg78
# Removing edge from alg76 to alg78
# Adding edge from alg76 to alg79
# Adding edge from alg77 to alg79
# ['alg73', 'alg74', 'alg75'] alg78
# ['alg78', 'alg76', 'alg77'] alg79
# Removing edge from alg78 to alg79
# Removing edge from alg77 to alg79
# ['alg79'] alg80
# Adding edge from alg76 to alg80
# Adding edge from alg77 to alg80
# Adding edge from alg78 to alg80
# Removing edge from alg79 to alg80
# Adding edge from alg79 to alg81
# ['alg76', 'alg77', 'alg78'] alg80
# Removing edge from alg78 to alg80
# ['alg80', 'alg79'] alg81
# Adding edge from alg76 to alg81
# Adding edge from alg77 to alg81
# Adding edge from alg78 to alg81
# Removing edge from alg80 to alg81
# Removing edge from alg79 to alg81
# Adding edge from alg79 to alg82
# Adding edge from alg80 to alg82
# ['alg76', 'alg77', 'alg78'] alg81
# Removing edge from alg78 to alg81
# ['alg81', 'alg79', 'alg80'] alg82
# Removing edge from alg81 to alg82
# ['alg82'] alg83
# Adding edge from alg79 to alg83
# Adding edge from alg80 to alg83
# Adding edge from alg81 to alg83
# Removing edge from alg82 to alg83
# Adding edge from alg82 to alg84
# ['alg79', 'alg80', 'alg81'] alg83
# Removing edge from alg81 to alg83
# ['alg83', 'alg82'] alg84
# Adding edge from alg79 to alg84
# Adding edge from alg80 to alg84
# Adding edge from alg81 to alg84
# Removing edge from alg83 to alg84
# Removing edge from alg82 to alg84
# Adding edge from alg82 to alg85
# Adding edge from alg83 to alg85
# ['alg79', 'alg80', 'alg81'] alg84
# ['alg84', 'alg82', 'alg83'] alg85
# Adding edge from alg79 to alg85
# Adding edge from alg80 to alg85
# Adding edge from alg81 to alg85
# Removing edge from alg84 to alg85
# Removing edge from alg82 to alg85
# Removing edge from alg83 to alg85
# Adding edge from alg82 to alg86
# Adding edge from alg83 to alg86
# Adding edge from alg84 to alg86
# ['alg79', 'alg80', 'alg81'] alg85
# ['alg85', 'alg82', 'alg83', 'alg84'] alg86
# Removing edge from alg85 to alg86
# Removing edge from alg83 to alg86
# Removing edge from alg84 to alg86
# ['alg86'] alg87
# Adding edge from alg82 to alg87
# Adding edge from alg83 to alg87
# Adding edge from alg84 to alg87
# Adding edge from alg85 to alg87
# Removing edge from alg86 to alg87
# Adding edge from alg86 to alg88
# ['alg82', 'alg83', 'alg84', 'alg85'] alg87
# Removing edge from alg85 to alg87
# ['alg87', 'alg86'] alg88
# Adding edge from alg82 to alg88
# Adding edge from alg83 to alg88
# Adding edge from alg84 to alg88
# Adding edge from alg85 to alg88
# Removing edge from alg87 to alg88
# Removing edge from alg86 to alg88
# Adding edge from alg86 to alg89
# Adding edge from alg87 to alg89
# ['alg82', 'alg83', 'alg84', 'alg85'] alg88
# ['alg88', 'alg86', 'alg87'] alg89
# Removing edge from alg88 to alg89
# Removing edge from alg87 to alg89
# ['alg89'] alg90
# Adding edge from alg86 to alg90
# Adding edge from alg87 to alg90
# Adding edge from alg88 to alg90
# Removing edge from alg89 to alg90
# Adding edge from alg89 to alg91
# ['alg86', 'alg87', 'alg88'] alg90
# Removing edge from alg88 to alg90
# ['alg90', 'alg89'] alg91
# Adding edge from alg86 to alg91
# Adding edge from alg87 to alg91
# Adding edge from alg88 to alg91
# Removing edge from alg90 to alg91
# Removing edge from alg89 to alg91
# Adding edge from alg89 to alg92
# Adding edge from alg90 to alg92
# ['alg86', 'alg87', 'alg88'] alg91
# ['alg91', 'alg89', 'alg90'] alg92
# Removing edge from alg91 to alg92
# Removing edge from alg90 to alg92
# ['alg92'] alg93
# Adding edge from alg89 to alg93
# Adding edge from alg90 to alg93
# Adding edge from alg91 to alg93
# Removing edge from alg92 to alg93
# Adding edge from alg92 to alg94
# ['alg89', 'alg90', 'alg91'] alg93
# Removing edge from alg91 to alg93
# ['alg93', 'alg92'] alg94
# Removing edge from alg93 to alg94
# ['alg94'] alg95
# Adding edge from alg92 to alg95
# Adding edge from alg93 to alg95
# Removing edge from alg94 to alg95
# Adding edge from alg94 to alg96
# ['alg92', 'alg93'] alg95
# Removing edge from alg93 to alg95
# ['alg95', 'alg94'] alg96
# Adding edge from alg92 to alg96
# Adding edge from alg93 to alg96
# Removing edge from alg95 to alg96
# Removing edge from alg94 to alg96
# Adding edge from alg94 to alg97
# Adding edge from alg95 to alg97
# ['alg92', 'alg93'] alg96
# Removing edge from alg93 to alg96
# ['alg96', 'alg94', 'alg95'] alg97
# Adding edge from alg92 to alg97
# Adding edge from alg93 to alg97
# Removing edge from alg96 to alg97
# Removing edge from alg94 to alg97
# Removing edge from alg95 to alg97
# Adding edge from alg94 to alg98
# Adding edge from alg95 to alg98
# Adding edge from alg96 to alg98
# ['alg92', 'alg93'] alg97
# ['alg97', 'alg94', 'alg95', 'alg96'] alg98
# Removing edge from alg97 to alg98
# ['alg98'] alg99
# Adding edge from alg94 to alg99
# Adding edge from alg95 to alg99
# Adding edge from alg96 to alg99
# Adding edge from alg97 to alg99
# Removing edge from alg98 to alg99
# ['alg94', 'alg95', 'alg96', 'alg97'] alg99
# Removing edge from alg97 to alg99
# None None

# %%
history[-1]

# %%
history[-1].render("dfg-100.pdf")
# Out:
# 'dfg-100.pdf.pdf'

# %%
ranks
# Out:
#    case:concept:name  case:rank:q25-q75
# 0               alg0                  0
# 1               alg1                  0
# 2               alg2                  0
# 3               alg3                  1
# 4               alg4                  1
# ..               ...                ...
# 94             alg94                 32
# 95             alg95                 32
# 97             alg97                 32
# 98             alg98                 33
# 99             alg99                 33
#
# [100 rows x 2 columns]

# %%
h0_f = ['alg0', 'alg1', 'alg2'] 
compareAlgs2 = CompareAlgs(data, h0_f)
rank2 = RankBFS(h0_f,compareAlgs2)
# Out:
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2

# %%
history2, ranks2 = rank2.rank_algorithms(q_min=25,q_max=75)
# Out:
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None

# %%
history2[-1]

# %%
fig = mv.show_measurements_violinplot(h0_f,scale=1.2)

# %%
q_maxs=[95, 90, 85, 80, 75, 70, 65, 55]
q_mins=[5, 10, 15, 20, 25, 30, 35, 45]

# %%
df_rank, df_mean = rank2.calculate_mean_rank(q_maxs=q_maxs, q_mins=q_mins)
# Out:
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# Removing edge from alg0 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# Removing edge from alg0 to alg1
# Adding edge from alg0 to alg2
# ['alg1', 'alg0'] alg2
# Removing edge from alg1 to alg2
# None None
# Adding edge from alg0 to alg1
# Adding edge from alg1 to alg2
# ['alg0'] alg1
# ['alg1'] alg2
# None None

# %%
df_mean
# Out:
#   case:concept:name  case:mean-rank
# 0              alg0           0.000
# 1              alg1           0.125
# 2              alg2           0.500

# %%
df_rank
# Out:
#                    case:rank:q5-q95  ...  case:rank:q45-q55
# case:concept:name                    ...
# alg0                              0  ...                  0
# alg1                              0  ...                  1
# alg2                              0  ...                  2
#
# [3 rows x 8 columns]
