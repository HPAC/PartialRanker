# %%
from algorithm_ranking import MeasurementsSimulator, MeasurementsVisualizer, RankVariantsDFGTr, RankVariantsSort2

# %%
import pandas as pd
import numpy as np

# %%
cfg = {}
cfg['t0']  = [0.2,0.01] #[mean, std]
cfg['t1']  = [0.3,0.015]
cfg['t2']  = [0.4,0.01]
cfg['t3']  = [0.5,0.01]
h0 = list(cfg.keys())

# %%
ms = MeasurementsSimulator(cfg, 'normal',seed=159) 
ms.measure(15,1)

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0)
fig = mv.show_measurements_boxplots(tick_size=14,scale=1.0)

# %%
fig.savefig("pr-def2-1.pdf", format="pdf", bbox_inches="tight")

# %%
cfg = {}
cfg['t0']  = [0.3,0.015]
cfg['t1']  = [0.3,0.015]
cfg['t2']  = [0.3,0.015]
cfg['t3']  = [0.5,0.01] #[mean, std]
h0 = list(cfg.keys())

# %%
ms = MeasurementsSimulator(cfg, 'normal',seed=159) 
ms.measure(15,1)

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0)
fig = mv.show_measurements_boxplots(tick_size=14,scale=1.0)

# %%
fig.savefig("pr-def2-2.pdf", format="pdf", bbox_inches="tight")

# %%
cfg = {}
cfg['t0']  = [0.3,0.005]
cfg['t1']  = [0.31,0.03]
cfg['t2']  = [0.32,0.005]
cfg['t3']  = [0.43,0.01] #[mean, std]
h0 = list(cfg.keys())

# %%
ms = MeasurementsSimulator(cfg, 'normal',seed=159) 
ms.measure(15,1)

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0)
fig = mv.show_measurements_boxplots(tick_size=14,scale=1.0)

# %%
fig.savefig("pr-def2-3.pdf", format="pdf", bbox_inches="tight")
