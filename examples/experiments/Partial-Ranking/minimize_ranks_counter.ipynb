# %%
from algorithm_ranking import MeasurementsSimulator, MeasurementsVisualizer, RankVariantsSort2, RankVariantsDFGTr, RankVariantsDFGBrute

# %%
import pandas as pd
import numpy as np
import random

# %%
n1 = [0.2, 0.02]
n2 = [0.3,0.02]
cfg = {}

for i in range(5):
    cfg['t{}'.format(i)] = n1

for i in range(5,10):
    cfg['t{}'.format(i)] = n2
#cfg
h0 = list(cfg.keys())
#random.shuffle(h0)

# %%
ms = MeasurementsSimulator(cfg, 'normal',seed=512) #5, 61 (149, 5, eg for not always the min rank)
ms.measure(3,1) # 3 and 10#

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.5)

# %%
##fig.savefig("gviz/minrank-eg1.pdf", format="pdf", bbox_inches="tight")

# %%
rvDFG = RankVariantsDFGTr(ms.get_alg_measurements(), h0)

# %%
rvDFG.rank_variants()
# Out:
#   case:concept:name  case:rank:q75-q25
# 0                t0                  0
# 1                t1                  0
# 2                t2                  1
# 3                t3                  1
# 4                t4                  1
# 5                t6                  2
# 6                t8                  2
# 7                t9                  2
# 8                t5                  3
# 9                t7                  4

# %%
rvDFG.graph.transitivity_reduction()
g = rvDFG.graph.visualize()
g

# %%
g.edge('t6','t7',color='red')

# %%
g

# %%
g.render(filename='gviz/minrank-eg4-dfg', format='svg')
# Out:
# 'gviz/minrank-eg4-dfg.svg'

# %%
h0_ = rvDFG.graph.get_separable_arrangement()
h0_
# Out:
# ['t1', 't0', 't3', 't4', 't2', 't9', 't6', 't8', 't5', 't7']

# %%
rv2 = RankVariantsSort2(ms.get_alg_measurements(), h0_)
rv2.rank_variants()
# Out:
#   case:concept:name  case:rank:q75-q25
# 0                t1                  0
# 1                t0                  0
# 2                t3                  0
# 3                t4                  0
# 4                t2                  0
# 5                t9                  1
# 6                t6                  1
# 7                t8                  1
# 8                t5                  1
# 9                t7                  2

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0_)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.4)

# %%
fig.savefig("gviz/minrank-eg4-r.svg", format="svg", bbox_inches="tight")

# %%
h0_x = h0_.copy()
h0_x[7] = 't5'
h0_x[8] = 't8'
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0_x)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.4)

# %%
fig.savefig("gviz/minrank-eg4-c.svg", format="svg", bbox_inches="tight")

# %%
n1 = [0.2, 0.02]
n2 = [0.3,0.02]
cfg = {}

for i in range(10):
    cfg['t{}'.format(i)] = n1

for i in range(10,20):
    cfg['t{}'.format(i)] = n2
#cfg
h0 = list(cfg.keys())

# %%
ms = MeasurementsSimulator(cfg, 'normal',seed=97) #5, 61 (149, 5, eg for not always the min rank)
ms.measure(3,1) # 3 and 10#

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.3)

# %%
rvDFG = RankVariantsDFGTr(ms.get_alg_measurements(), h0)
rvDFG.rank_variants()

rvDFG.graph.transitivity_reduction()
g = rvDFG.graph.visualize()
g

# %%
h0_ = rvDFG.graph.get_separable_arrangement()
h0_
# Out:
# ['t0',
#  't7',
#  't1',
#  't2',
#  't4',
#  't3',
#  't8',
#  't9',
#  't6',
#  't5',
#  't17',
#  't19',
#  't12',
#  't11',
#  't14',
#  't15',
#  't16',
#  't10',
#  't18',
#  't13']

# %%
rv2 = RankVariantsSort2(ms.get_alg_measurements(), h0_)
rv2.rank_variants()
# Out:
#    case:concept:name  case:rank:q75-q25
# 0                 t0                  0
# 1                 t7                  0
# 2                 t1                  0
# 3                 t2                  0
# 4                 t4                  0
# 5                 t3                  0
# 6                 t8                  1
# 7                 t9                  1
# 8                 t6                  1
# 9                 t5                  1
# 10               t17                  2
# 11               t19                  2
# 12               t12                  2
# 13               t11                  2
# 14               t14                  2
# 15               t15                  2
# 16               t16                  2
# 17               t10                  2
# 18               t18                  2
# 19               t13                  2

# %%
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0_)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.3)

# %%
h0_x = h0_.copy()
h0_x[3] = 't3'
h0_x[5] = 't2'
mv = MeasurementsVisualizer(ms.get_alg_measurements(), h0_x)
fig = mv.show_measurements_boxplots(tick_size=12, scale=0.3)

# %%
rv2 = RankVariantsSort2(ms.get_alg_measurements(), h0_x)
rv2.rank_variants()
# Out:
#    case:concept:name  case:rank:q75-q25
# 0                 t0                  0
# 1                 t7                  0
# 2                 t1                  0
# 3                 t3                  0
# 4                 t4                  0
# 5                 t2                  0
# 6                 t8                  0
# 7                 t9                  0
# 8                 t6                  0
# 9                 t5                  0
# 10               t17                  1
# 11               t19                  1
# 12               t12                  1
# 13               t11                  1
# 14               t14                  1
# 15               t15                  1
# 16               t16                  1
# 17               t10                  1
# 18               t18                  1
# 19               t13                  1
