# %% [markdown]
# ### Measurements Visualization

# %%
from partial_ranker import MeasurementsSimulator, MeasurementsVisualizer
import pandas as pd

# %%
M0 = {}
M0['t0']  = [0.30,0.005] # [mean, std]
M0['t1']  = [0.31,0.03]
M0['t2']  = [0.32,0.005]
M0['t3']  = [0.43,0.01]

ms = MeasurementsSimulator(M0,seed=159)
ms.measure(reps=15)
measurements = ms.get_measurements()

mv = MeasurementsVisualizer(measurements)
fig = mv.show_measurements_boxplots(scale=0.8)

# %%
M1 = {}
M1['t0']  = [0.2,0.01] # [mean, std]
M1['t1']  = [0.3,0.01]
M1['t2']  = [0.4,0.01]
M1['t3']  = [0.5,0.01]

ms = MeasurementsSimulator(M1,seed=159)
ms.measure(reps=15)
measurements = ms.get_measurements()

mv = MeasurementsVisualizer(measurements)
fig = mv.show_measurements_boxplots(scale=0.8)

# %%
M2 = {}
M2['t0']  = [0.3,0.01] # [mean, std]
M2['t1']  = [0.3,0.01]
M2['t2']  = [0.3,0.01]
M2['t3']  = [0.5,0.01]

ms = MeasurementsSimulator(M2,seed=159)
ms.measure(reps=15)
measurements = ms.get_measurements()

mv = MeasurementsVisualizer(measurements)
fig = mv.show_measurements_boxplots(scale=0.8)
